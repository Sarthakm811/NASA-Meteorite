# %%
import pandas as pd
import numpy as np

# %%
star=pd.read_csv("/content/meteorite-landings.csv")

# %%
star.head()
# Out:
#        name   id nametype     recclass      mass  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong               GeoLocation
# 0    6.08333     (50.775000, 6.083330)
# 1   10.23333    (56.183330, 10.233330)
# 2 -113.00000  (54.216670, -113.000000)
# 3  -99.90000   (16.883330, -99.900000)
# 4  -64.95000  (-33.166670, -64.950000)

# %%
star.isna().sum()
# Out:
# name              0
# id                0
# nametype          0
# recclass          0
# mass            131
# fall              0
# year            288
# reclat         7315
# reclong        7315
# GeoLocation    7315
# dtype: int64

# %%
star.dropna(inplace=True)

# %%
star["fall"].value_counts()
# Out:
# fall
# Found    37051
# Fell      1065
# Name: count, dtype: int64

# %%
star['nametype'].value_counts()
# Out:
# nametype
# Valid     38095
# Relict       21
# Name: count, dtype: int64

# %%
s1=star.groupby("year")

# %%
f=s1["fall"].value_counts()

# %%
star[["fall","year"]].value_counts()
# Out:
# fall   year
# Found  1979.0    3043
#        1988.0    2289
#        1998.0    2138
#        2003.0    1745
#        2006.0    1611
#                  ...
# Fell   1806.0       1
#        1490.0       1
#        1399.0       1
#        860.0        1
# Found  2101.0       1
# Name: count, Length: 440, dtype: int64

# %%
star['mass'].mean()
# Out:
# np.float64(15600.306111344315)

# %%
star['mass'].max()
# Out:
# 60000000.0

# %%
star["mass_in_kg"]=star["mass"]/1000

# %%
star["mass_in_kg"].min()
# Out:
# 0.0

# %%
star["mass_in_kg"].mean()
# Out:
# np.float64(15.600306111344315)

# %%
star["mass_in_kg"].max()
# Out:
# 60000.0

# %%
star['recclass'].value_counts()
# Out:
# recclass
# L6                7519
# H5                6243
# H6                3898
# H4                3880
# L5                3264
#                   ...
# EH7                  1
# LL3-5                1
# H3.8/3.9             1
# L/LL                 1
# Mesosiderite-C       1
# Name: count, Length: 422, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
star["fall"].value_counts()
# Out:
# fall
# Found    37051
# Fell      1065
# Name: count, dtype: int64

# %%
fc=star["fall"].value_counts()
fc.plot( kind="bar",
    color=["r", "k"],
    title="Meteorites: Fell vs Found")
# Out:
# <Axes: title={'center': 'Meteorites: Fell vs Found'}, xlabel='fall'>

# %%
star["nametype"].value_counts()
# Out:
# nametype
# Valid     38095
# Relict       21
# Name: count, dtype: int64

# %%
rc=star.groupby("recclass")

# %%
rc["mass_in_kg"].sum()
# Out:
# recclass
# Acapulcoite                7.633018
# Acapulcoite/Lodranite      0.126760
# Acapulcoite/lodranite      0.003500
# Achondrite-prim            2.243000
# Achondrite-ung            26.227400
#                             ...
# Stone-ung                  0.000630
# Ureilite                 110.924070
# Ureilite-an                3.983700
# Ureilite-pmict             5.516300
# Winonaite                 26.754030
# Name: mass_in_kg, Length: 422, dtype: float64

# %%
plt.plot(rc["mass_in_kg"].sum())

# %%
plt.scatter(star["reclong"],star["reclat"])

# %%
star["recclass"].value_counts().head(15).plot(kind="bar",
         color=["g","y"])
# Out:
# <Axes: xlabel='recclass'>
